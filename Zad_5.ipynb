# %% [markdown]
# <a href="https://colab.research.google.com/github/RyniekSzkola/175IC-machine-learning/blob/main/Zad_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt

# %%
sns.set(font_scale=1.3)
np.random.seed(44)

raw_data = load_iris()
all_data=raw_data.copy()

data = all_data['data']
target = all_data['target']
feature_names = all_data['feature_names']
target_names = all_data['target_names']

df= pd.DataFrame(np.c_[data,target],columns=feature_names+['target'])

# %%
data = data[:, [0,1]]
target = df['target'].apply(int).values

print(f'{data[:5]}\n')
# Out:
# [[5.1 3.5]
#  [4.9 3. ]
#  [4.7 3.2]
#  [4.6 3.1]
#  [5.  3.6]]
#
# [0 0 0 0 0]

# %%
classifier = RandomForestClassifier(n_estimators=54)
X_train,X_test,y_train,y_test = train_test_split(data,target)
classifier.fit(X_train, y_train)
plt.figure(figsize=(10,8))
plot_decision_regions(data,target,classifier)
plt.xlabel(feature_names[0])
plt.ylabel(feature_names[1])
plt.show
# Out:
# /usr/local/lib/python3.6/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning:
#
# Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
# <function matplotlib.pyplot.show>

# %%
y_pred = classifier.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.5789473684210527

# %%
importances = classifier.feature_importances_
print(importances)
# Out:
# [0.66395327 0.33604673]
